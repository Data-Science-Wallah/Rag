# %%
# %%capture
# !pip install -q pypdf
# !pip install -q python-dotenv
# !pip install -q transformers
# !CMAKE_ARGS="-DLLAMA_CUBLAS=on" FORCE_CMAKE=1 pip install  llama-cpp-python --no-cache-dir
# !pip install -q llama-index
# !pip -q install sentence-transformers
# !pip install langchain

# %%
import logging
import sys

logging.basicConfig(stream=sys.stdout, level=logging.INFO)
logging.getLogger().addHandler(logging.StreamHandler(stream=sys.stdout))

from llama_index import VectorStoreIndex, SimpleDirectoryReader, ServiceContext

# %%
documents = SimpleDirectoryReader("/content/sample_data/data").load_data()

# %%
import torch

from llama_index.llms import LlamaCPP
from llama_index.llms.llama_utils import messages_to_prompt, completion_to_prompt
llm = LlamaCPP(
    # You can pass in the URL to a GGML model to download it automatically
    model_url='https://huggingface.co/TheBloke/Mistral-7B-Instruct-v0.1-GGUF/resolve/main/mistral-7b-instruct-v0.1.Q4_K_M.gguf',
    # optionally, you can set the path to a pre-downloaded model instead of model_url
    model_path=None,
    temperature=0.1,
    max_new_tokens=256,
    # llama2 has a context window of 4096 tokens, but we set it lower to allow for some wiggle room
    context_window=3900,
    # kwargs to pass to __call__()
    generate_kwargs={},
    # kwargs to pass to __init__()
    # set to at least 1 to use GPU
    model_kwargs={"n_gpu_layers": -1},
    # transform inputs into Llama2 format
    messages_to_prompt=messages_to_prompt,
    completion_to_prompt=completion_to_prompt,
    verbose=True,
)

# %%
from langchain.embeddings.huggingface import HuggingFaceEmbeddings
from llama_index.embeddings.langchain import LangchainEmbedding

from llama_index import ServiceContext

embed_model = LangchainEmbedding(
  HuggingFaceEmbeddings(model_name="thenlper/gte-large")
)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/385 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/67.9k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/57.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/619 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/670M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/342 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/712k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/191 [00:00<?, ?B/s]

# %%
service_context = ServiceContext.from_defaults(
    chunk_size=256,
    llm=llm,
    embed_model=embed_model
)

# %%
index = VectorStoreIndex.from_documents(documents, service_context=service_context)

# %%
query_engine = index.as_query_engine()

# %%
while True:
  query=input()
  response = query_engine.query(query)
  print(response)
# Out:
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     669.25 ms
# llama_print_timings:      sample time =     104.26 ms /   192 runs   (    0.54 ms per token,  1841.55 tokens per second)
# llama_print_timings: prompt eval time =     849.11 ms /   647 tokens (    1.31 ms per token,   761.97 tokens per second)
# llama_print_timings:        eval time =    5453.78 ms /   191 runs   (   28.55 ms per token,    35.02 tokens per second)
# llama_print_timings:       total time =    6953.04 ms /   838 tokens
#  TRULICITY® is a glucagon-like peptide-1 (GLP-1) receptor agonist indicated for the treatment of type 2 diabetes mellitus in adults and pediatric patients aged 10 years and older. It is used as an adjunct to diet and exercise to improve glycemic control and to reduce the risk of major adverse cardiovascular events in adults with type 2 diabetes mellitus who have established cardiovascular disease or multiple cardiovascular risk factors. However, it has not been studied in patients with a history of pancreatitis, and other antidiabetic therapies should be considered in these patients (1, 5.2). It is important to counsel patients regarding the potential risk of medullary thyroid carcinoma (MTC) and symptoms of thyroid tumors (4, 5.1).
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     669.25 ms
# llama_print_timings:      sample time =      27.43 ms /    52 runs   (    0.53 ms per token,  1896.08 tokens per second)
# llama_print_timings: prompt eval time =     853.93 ms /   659 tokens (    1.30 ms per token,   771.73 tokens per second)
# llama_print_timings:        eval time =    1462.56 ms /    51 runs   (   28.68 ms per token,    34.87 tokens per second)
# llama_print_timings:       total time =    2483.55 ms /   710 tokens
#  I am unable to determine if Trulicity is available in India based on the provided context information. The document only mentions the indications and usage of Trulicity in the United States and does not provide any information about its availability in other countries.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     669.25 ms
# llama_print_timings:      sample time =     124.09 ms /   219 runs   (    0.57 ms per token,  1764.79 tokens per second)
# llama_print_timings: prompt eval time =     880.96 ms /   700 tokens (    1.26 ms per token,   794.59 tokens per second)
# llama_print_timings:        eval time =    6371.03 ms /   218 runs   (   29.22 ms per token,    34.22 tokens per second)
# llama_print_timings:       total time =    8129.60 ms /   918 tokens
#  Based on the provided context information, TRULICITY is a medication used to treat type 2 diabetes. The study found that patients who received TRULICITY had a higher percentage of discontinuations due to gastrointestinal (GI) adverse reactions compared to patients who received placebo. The most common GI adverse reactions reported in TRULICITY-treated patients were constipation, flatulence, abdominal distension, gastroesophageal reflux disease, and eructation. The severity of these adverse reactions was graded as mild, moderate, or severe. Additionally, sinus tachycardia was reported more frequently in patients exposed to TRULICITY, with episodes of sinus tachycardia associated with a concomitant increase from baseline in heart rate of ≥15 beats per minute reported in some patients. It's important to note that this information is based on the study provided in the context and may not be representative of all patients or situations.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     669.25 ms
# llama_print_timings:      sample time =      76.21 ms /   143 runs   (    0.53 ms per token,  1876.39 tokens per second)
# llama_print_timings: prompt eval time =     920.06 ms /   676 tokens (    1.36 ms per token,   734.73 tokens per second)
# llama_print_timings:        eval time =    4184.98 ms /   142 runs   (   29.47 ms per token,    33.93 tokens per second)
# llama_print_timings:       total time =    5601.38 ms /   818 tokens
#  Based on the provided context information, it appears that TRULICITY is used to treat type 2 diabetes by reducing fasting and postprandial glucose concentrations, increasing first- and second-phase insulin secretion, stimulating glucose-dependent insulin secretion, and reducing glucagon secretion. However, there is no mention of its use for weight loss. It's important to note that while TRULICITY may have some weight loss benefits due to its glucose-lowering effects, it's not primarily indicated for weight loss purposes. It's always recommended to consult with a healthcare professional for proper diagnosis and treatment of medical conditions.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-e57627802c61> in <cell line: 1>()
#       1 while True:
# ----> 2   query=input()
#       3   response = query_engine.query(query)
#       4   print(response)
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
